# %%
import pandas as pd
from sqlalchemy import create_engine

# Load the cleaned dataset
df = pd.read_csv("swiss_no_outliers_and_cleaned.csv")

# Establish a connection to your MySQL database
engine = create_engine("mysql+pymysql://root:root@localhost/ads")

# Save the DataFrame to the MySQL database
df.to_sql(name='apartmentszuerich', con=engine, if_exists='replace', index=False)
# Out:
# 8407

# %%
import pandas as pd
from sqlalchemy import create_engine

# Establish a connection to your MySQL database
engine = create_engine("mysql+pymysql://root:root@localhost/ads")

# Query 1: Select rows where Rooms is between 2 and 4 (inclusive)
query1 = "SELECT * FROM apartmentszuerich WHERE Rooms BETWEEN 2 AND 4"

# Execute Query 1 and store the result in a DataFrame
result_df1 = pd.read_sql(query1, con=engine)

# Display the result of Query 1
print("Query 1 Result:")
print(result_df1)
print()
# Out:
# Query 1 Result:
#       Rooms  Footage  Rent                                     address
# 0       3.5       63  1740              Schmittegass 11, 8197 Rafz, ZH  \
# 1       3.5      104  2270     Zürcherstrasse 163, 8406 Winterthur, ZH
# 2       3.5       83  2290      Usterstrasse 125, 8620 Wetzikon ZH, ZH
# 3       2.5       57  1580         Mörlerstrasse 22, 8248 Uhwiesen, ZH
# 4       2.5       60  2600          Buchserstrasse, 8157 Dielsdorf, ZH
# ...     ...      ...   ...                                         ...
# 5551    3.5       91  1200       Rte de Recolaine 79, 2824 Vicques, JU
# 5552    3.0       80  1500                         2900 Porrentruy, JU
# 5553    3.5       75  1275             Rue du soleil, 2907 Rocourt, JU
# 5554    3.5       65   975    Rue Saint-Germain 3, 2853 Courfaivre, JU
# 5555    3.5       71   980  Route de Fontenais 31, 2900 Porrentruy, JU
#
#                                                   title description
# ...

# %%
# Query 2: Select rows where Rent is greater than 2000
query2 = "SELECT * FROM apartmentszuerich WHERE Rent > 2000"

# Execute Query 2 and store the result in a DataFrame
result_df2 = pd.read_sql(query2, con=engine)

# Display the result of Query 2
print("Query 2 Result:")
print(result_df2)
# Out:
# Query 2 Result:
#       Rooms  Footage  Rent                                            address
# 0       5.5      150  2480               Hofackerstrasse 6, 8444 Henggart, ZH  \
# 1       3.5      104  2270            Zürcherstrasse 163, 8406 Winterthur, ZH
# 2       3.5       83  2290             Usterstrasse 125, 8620 Wetzikon ZH, ZH
# 3       2.5       60  2600                 Buchserstrasse, 8157 Dielsdorf, ZH
# 4       2.5       73  3250                     Marktgasse 13, 8302 Kloten, ZH
# ...     ...      ...   ...                                                ...
# 2061    5.0      100  2955  Chemin de la Fontaine 2, 1224 Chêne-Bougeries, GE
# 2062    3.0       60  2250                    Rue Dizerens 1, 1205 Genève, GE
# 2063    4.5      107  2030              Rue des Téxérans 1, 2800 Delémont, JU
# 2064    5.5      157  2060         Rue des Tourterelles 22, 2800 Delémont, JU
# 2065    4.5      140  3000          Faubourg de France 9, 2900 Porrentruy, JU
#
# ...
